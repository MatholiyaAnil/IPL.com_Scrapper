# %%
import requests
import json
import re
import pandas as pd

base_url = 'https://ipl-stats-sports-mechanic.s3.ap-south-1.amazonaws.com/ipl/feeds/'

Matchid = [1046, 1045, 1044, 1043, 925, 924, 923, 922, 921, 920, 919, 918, 917, 916, 915, 914, 913, 912, 911, 910,
           909, 908, 907, 906, 905, 904, 903, 902, 900, 901, 899, 898, 897, 896, 895, 894, 893, 892, 891, 890, 889,
           888, 887, 886, 885, 884, 883, 882, 881, 880, 879, 878, 877, 876, 875, 874, 873, 872, 871, 870, 869, 868,
           867, 866, 865, 864, 863, 862, 861, 860, 859, 858, 857, 856]

new_urls = [f'{base_url}{match_id}-Innings1.js' for match_id in Matchid]

for url in new_urls:
    response = requests.get(url)

    # Assuming the response text is stored in a variable called 'response'
    start_index = response.text.find('(') + 1
    end_index = response.text.rfind(')')

    json_data = response.text[start_index:end_index]
    data = json.loads(json_data)

    if "OverHistory" in data["Innings1"]:
        over_history = data["Innings1"]["OverHistory"]

        # Create a list of dictionaries representing rows
        rows = []
        for item in over_history:
            rows.append(item)

        df = pd.DataFrame(rows)

        # Save DataFrame as CSV with the file name derived from the test URL
        file_name = re.search(r'/(\d+-\w+)\.', url).group(1)  # Extracts '1045-Innings1' from the URL
        csv_file_name = f"{file_name}-OverHistory.csv"  # Append 'OverHistory' to the file name
        df.to_csv(csv_file_name, index=False)

        print(f"{csv_file_name}")
# Out:
# 1046-Innings1-OverHistory.csv
# 1045-Innings1-OverHistory.csv
# 1044-Innings1-OverHistory.csv
# 1043-Innings1-OverHistory.csv
# 925-Innings1-OverHistory.csv
# 924-Innings1-OverHistory.csv
# 923-Innings1-OverHistory.csv
# 922-Innings1-OverHistory.csv
# 921-Innings1-OverHistory.csv
# 920-Innings1-OverHistory.csv
# 919-Innings1-OverHistory.csv
# 918-Innings1-OverHistory.csv
# 917-Innings1-OverHistory.csv
# 916-Innings1-OverHistory.csv
# 915-Innings1-OverHistory.csv
# 914-Innings1-OverHistory.csv
# 913-Innings1-OverHistory.csv
# 912-Innings1-OverHistory.csv
# 911-Innings1-OverHistory.csv
# 910-Innings1-OverHistory.csv
# 909-Innings1-OverHistory.csv
# 908-Innings1-OverHistory.csv
# 907-Innings1-OverHistory.csv
# 906-Innings1-OverHistory.csv
# 905-Innings1-OverHistory.csv
# 904-Innings1-OverHistory.csv
# 903-Innings1-OverHistory.csv
# 902-Innings1-OverHistory.csv
# 900-Innings1-OverHistory.csv
# 901-Innings1-OverHistory.csv
# 899-Innings1-OverHistory.csv
# 898-Innings1-OverHistory.csv
# 897-Innings1-OverHistory.csv
# 896-Innings1-OverHistory.csv
# 895-Innings1-OverHistory.csv
# 894-Innings1-OverHistory.csv
# 893-Innings1-OverHistory.csv
# 892-Innings1-OverHistory.csv
# 891-Innings1-OverHistory.csv
# 890-Innings1-OverHistory.csv
# 889-Innings1-OverHistory.csv
# 888-Innings1-OverHistory.csv
# 887-Innings1-OverHistory.csv
# 886-Innings1-OverHistory.csv
# 885-Innings1-OverHistory.csv
# 884-Innings1-OverHistory.csv
# 883-Innings1-OverHistory.csv
# 882-Innings1-OverHistory.csv
# 881-Innings1-OverHistory.csv
# 880-Innings1-OverHistory.csv
# 879-Innings1-OverHistory.csv
# 878-Innings1-OverHistory.csv
# 877-Innings1-OverHistory.csv
# 876-Innings1-OverHistory.csv
# 875-Innings1-OverHistory.csv
# 874-Innings1-OverHistory.csv
# 873-Innings1-OverHistory.csv
# 872-Innings1-OverHistory.csv
# 871-Innings1-OverHistory.csv
# 870-Innings1-OverHistory.csv
# 869-Innings1-OverHistory.csv
# 868-Innings1-OverHistory.csv
# 867-Innings1-OverHistory.csv
# 866-Innings1-OverHistory.csv
# 865-Innings1-OverHistory.csv
# 864-Innings1-OverHistory.csv
# 863-Innings1-OverHistory.csv
# 862-Innings1-OverHistory.csv
# 861-Innings1-OverHistory.csv
# 860-Innings1-OverHistory.csv
# 859-Innings1-OverHistory.csv
# 858-Innings1-OverHistory.csv
# 857-Innings1-OverHistory.csv
# 856-Innings1-OverHistory.csv
